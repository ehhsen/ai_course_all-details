# %%
#file handlimg
# syntax  f=open("file_name","mode")
# deta = f.read()
# f.close
# creat text  file in pc, click on adderess and then write cmd at start then enter
# next write jupyter notebook in cmd enter
# gee for geeks and w3school for diff modes of file handling


f= open("/content/demo_1","r")
for _ in range(5):
  print(f.readline())
f.close()

# %% [markdown]
# **WRITING FILE**

# %%
# TWO METHODS
# OVER-RIDE/WRITE MODE
# APPEND MODE AT LAST
fi = open("/content/demo_1", "w")
fi.write("hello")
fi= open("/content/demo_1", )
print(fi.read())

# %% [markdown]
# **APPEND FILE**

# %%
fil = open("/content/demo_appending", "a")
fil.write("this is a new line of file")
fil = open("/content/demo_appending")
print(fil.read())
fil.close()

# %% [markdown]
# **ALTERNATE METHOD**

# %%
with open("demo3", "r") as d:
  print(d.read())

# %% [markdown]
# **DELETE FILE**

# %%
# we need os modiule/framework/library
import os
os.remove("demo3")

# %% [markdown]
# **PRACTISE**

# %%
#program for replacing and finding string
with open("practise", "w") as f:
  #opening to write
  f.write("Hi everyone \n Im AI, ML, DL trainee.\n I use java language for my projects.\n I like prigrammiung in java")
def check():
   # func for replacing
  with open("practise", "r+") as f:
    #open file and store it in count
    cont = f.read()
    #now replacing
    f.write(cont.replace("java", "python"))
    #printing
    print(cont)


def checkp():# func to check word projects
  with open("practise") as f: # opening
    cont = f.read()
  if "projects" in cont:  # simple checking
    print("yes project ")
  else:
    print("no")
    #calling
check()
checkp()
